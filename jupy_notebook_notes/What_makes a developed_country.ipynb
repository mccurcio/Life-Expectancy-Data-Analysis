# %% [markdown]
# # Life Expectancy Analysis & Modeling Using WHO & UN Data
#
# ## What makes a developed nation?
#
# To:&nbsp;&nbsp;&nbsp;&nbsp; [Magnimind](https://magnimindacademy.com/)
#
# From: Matt Curcio, matt.curcio.us@gmail.com
#
# Date: 2023-01-29
#
# Re:&nbsp;&nbsp;&nbsp;
#
# ---
#
# ## Executive Summary
#
# It lumps nations into the two standard categories, Developed and Developing, and several of these assignments seem questionable.
#
# Input: `Life_Expectancy_Data.csv`
#
# Output: `Clean_LE_Data_w_Means_1.csv`
#
# ---

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import plotly.express as px

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
path = '../data/processed/'
filename = 'Clean_LE_Regions_3.csv'

df = pd.read_csv(path+filename)

# Convert vars to categorical
df['Country'] = pd.Categorical(df['Country'])
df['Status'] = pd.Categorical(df['Status'])
df['Region'] = pd.Categorical(df['Region'])

#df.head()

# %%
# Pie chart of nation status
fig = plt.figure(figsize =(10, 7))
plt.pie(df, labels = Status)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 # Pie chart of nation status
#       2 fig = plt.figure(figsize =(10, 7))
# ----> 3 plt.pie(df['Status'], labels = Status)
#       5 plt.show()
#
# NameError: name 'Status' is not defined

# %% [markdown]
# ## Visualizing life expectancy of 193 countries by status

# %%
# Histogram and Boxplot of Life Expectancy

plt.figure(figsize=(8,4))
sns.set_theme(style="whitegrid")

plt.title('Histogram of Life Expectancies - Developed Vs Developing')
sns.histplot(data=df, x='LifeExpectancy', binwidth=2, kde=True, hue='Status')
plt.xlim(34, 91)
#plt.savefig('../data/assets/Histogram_Life_Expectancies_All_Countries.png')

plt.show()

# %%
import plotly.express as px

plt.figure(figsize=(12, 8))
fig = px.violin(df, y="LifeExpectancy",
                color="Status",
                box=True,
                points="all",
                hover_data=df.columns
                )

fig.update_layout(margin=dict(l=20, r=20, t=40, b=10),
                  paper_bgcolor="white",
                  title='All Points & Violin Plots of Nation Status'
                  )
fig.update_traces(meanline_visible=True)
fig.update_layout(violingap=0, violingroupgap=0, violinmode='overlay')

fig.show()
